# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# ## Contract Structure Analysis
#
# Examine characteristics of contracts that resulted in dead money.

# %%
# TODO: Load contract data
# Analyze:
# - Guaranteed money amounts
# - Contract length
# - Signing bonus vs salary structure
# - Player age at signing
# - Position

# %% [markdown]
# ## Analysis Plan
#
# 1. Categorize contract types
# 2. Calculate dead money rate by contract type
# 3. Identify high-risk contract features
# 4. Compare across positions
# 5. Assess team strategies
